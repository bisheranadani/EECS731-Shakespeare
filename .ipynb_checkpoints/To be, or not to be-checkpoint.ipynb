# %% [markdown]
# # Welcome to Shakespeare classifier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
df = pd.read_csv(Path("data/Shakespeare_data.csv"))

# %%
df.head()
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               NaN          NaN            NaN
# 1         2  Henry IV               NaN          NaN            NaN
# 2         3  Henry IV               NaN          NaN            NaN
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
df.dtypes
# Out:
# Dataline              int64
# Play                 object
# PlayerLinenumber    float64
# ActSceneLine         object
# Player               object
# PlayerLine           object
# dtype: object

# %% [markdown]
# ## We need to check for missing values

# %% [markdown]
# We find instances where PlayerLinenumber is NaN and replace it with 0

# %%
df.loc[df['PlayerLinenumber'].isnull()]
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine Player  \
# 0         1  Henry IV               NaN          NaN    NaN
# 1         2  Henry IV               NaN          NaN    NaN
# 2         3  Henry IV               NaN          NaN    NaN
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...

# %%
df['PlayerLinenumber'].fillna(0, inplace=True)

# %% [markdown]
# We do the same for ActSceneLine but we replace with the string "trans" for transition in the play

# %%
df.loc[df['ActSceneLine'].isnull()]
# Out:
#         Dataline            Play  PlayerLinenumber ActSceneLine  \
# 0              1        Henry IV               0.0          NaN
# 1              2        Henry IV               0.0          NaN
# 2              3        Henry IV               0.0          NaN
# 111          112        Henry IV              10.0          NaN
# 112          113        Henry IV              10.0          NaN
# 113          114        Henry IV              10.0          NaN
# 214          215        Henry IV              33.0          NaN
# 264          265        Henry IV              52.0          NaN
# 299          300        Henry IV              61.0          NaN
# 323          324        Henry IV              62.0          NaN
# 324          325        Henry IV              62.0          NaN
# 325          326        Henry IV              62.0          NaN
# 347          348        Henry IV               4.0          NaN
# 349          350        Henry IV               4.0          NaN
# 454          455        Henry IV              10.0          NaN
# 461          462        Henry IV              12.0          NaN
# 604          605        Henry IV              42.0          NaN
# 644          645        Henry IV              54.0          NaN
# 645          646        Henry IV              54.0          NaN
# 646          647        Henry IV              54.0          NaN
# 647          648        Henry IV              54.0          NaN
# 655          656        Henry IV               3.0          NaN
# 678          679        Henry IV              11.0          NaN
# 692          693        Henry IV              19.0          NaN
# 699          700        Henry IV              22.0          NaN
# 744          745        Henry IV              32.0          NaN
# 745          746        Henry IV              32.0          NaN
# 746          747        Henry IV              32.0          NaN
# 750          751        Henry IV               2.0          NaN
# 775          776        Henry IV               7.0          NaN
# ...          ...             ...               ...          ...
# 110533    110534  A Winters Tale             179.0          NaN
# 110549    110550  A Winters Tale             183.0          NaN
# 110563    110564  A Winters Tale             188.0          NaN
# 110578    110579  A Winters Tale             189.0          NaN
# 110609    110610  A Winters Tale             201.0          NaN
# 110723    110724  A Winters Tale             239.0          NaN
# 110736    110737  A Winters Tale             240.0          NaN
# 110737    110738  A Winters Tale             240.0          NaN
# 110738    110739  A Winters Tale             240.0          NaN
# 110739    110740  A Winters Tale             240.0          NaN
# 110793    110794  A Winters Tale               8.0          NaN
# 110847    110848  A Winters Tale              24.0          NaN
# 110885    110886  A Winters Tale              34.0          NaN
# 110896    110897  A Winters Tale              36.0          NaN
# 110957    110958  A Winters Tale              42.0          NaN
# 111020    111021  A Winters Tale              59.0          NaN
# 111027    111028  A Winters Tale              59.0          NaN
# 111028    111029  A Winters Tale              59.0          NaN
# 111029    111030  A Winters Tale              59.0          NaN
# 111048    111049  A Winters Tale               4.0          NaN
# 111055    111056  A Winters Tale               5.0          NaN
# 111143    111144  A Winters Tale              18.0          NaN
# 111155    111156  A Winters Tale              19.0          NaN
# 111206    111207  A Winters Tale              38.0          NaN
# 111207    111208  A Winters Tale              38.0          NaN
# 111208    111209  A Winters Tale              38.0          NaN
# 111232    111233  A Winters Tale               4.0          NaN
# 111330    111331  A Winters Tale              30.0          NaN
# 111336    111337  A Winters Tale              30.0          NaN
# 111395    111396  A Winters Tale              38.0          NaN
#
#                    Player                                         PlayerLine
# 0                     NaN                                              ACT I
# 1                     NaN                       SCENE I. London. The palace.
# 2                     NaN  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 111          WESTMORELAND                                             Exeunt
# 112          WESTMORELAND    SCENE II. London. An apartment of the Prince's.
# 113          WESTMORELAND             Enter the PRINCE OF WALES and FALSTAFF
# 214              FALSTAFF                                        Enter POINS
# 264          PRINCE HENRY                                      Exit Falstaff
# 299                 POINS                                         Exit Poins
# 323          PRINCE HENRY                                               Exit
# 324          PRINCE HENRY                     SCENE III. London. The palace.
# 325          PRINCE HENRY  Enter the KING, NORTHUMBERLAND, WORCESTER, HOT...
# 347         KING HENRY IV                                     Exit Worcester
# 349         KING HENRY IV                                           To North
# 454         KING HENRY IV                Exeunt King Henry, Blunt, and train
# 461        NORTHUMBERLAND                                 Re-enter WORCESTER
# 604     EARL OF WORCESTER                                  To Northumberland
# 644               HOTSPUR                                             Exeunt
# 645               HOTSPUR                                             ACT II
# 646               HOTSPUR                   SCENE I. Rochester. An inn yard.
# 647               HOTSPUR         Enter a Carrier with a lantern in his hand
# 655         First Carrier                              Enter another Carrier
# 678         First Carrier                                     Enter GADSHILL
# 692        Second Carrier                                    Exeunt carriers
# 699              GADSHILL                                  Enter Chamberlain
# 744              GADSHILL                                             Exeunt
# 745              GADSHILL              SCENE II. The highway, near Gadshill.
# 746              GADSHILL                       Enter PRINCE HENRY and POINS
# 750          PRINCE HENRY                                     Enter FALSTAFF
# 775              FALSTAFF                                       They whistle
# ...                   ...                                                ...
# 110533            CAMILLO           FLORIZEL and AUTOLYCUS exchange garments
# 110549            CAMILLO                               Giving it to PERDITA
# 110563            CAMILLO              Exeunt FLORIZEL, PERDITA, and CAMILLO
# 110578          AUTOLYCUS                        Re-enter Clown and Shepherd
# 110609          AUTOLYCUS                          Takes off his false beard
# 110723           Shepherd                          Exeunt Shepherd and Clown
# 110736          AUTOLYCUS                                               Exit
# 110737          AUTOLYCUS                                              ACT V
# 110738          AUTOLYCUS                SCENE I. A room in LEONTES' palace.
# 110739          AUTOLYCUS  Enter LEONTES, CLEOMENES, DION, PAULINA, and S...
# 110793            PAULINA                                         To LEONTES
# 110847            PAULINA                                  Enter a Gentleman
# 110885            LEONTES                        Exeunt CLEOMENES and others
# 110896            LEONTES  Re-enter CLEOMENES and others, with FLORIZEL a...
# 110957            LEONTES                                       Enter a Lord
# 111020            LEONTES                                        To FLORIZEL
# 111027            LEONTES                                             Exeunt
# 111028            LEONTES                  SCENE II. Before LEONTES' palace.
# 111029            LEONTES                    Enter AUTOLYCUS and a Gentleman
# 111048    First Gentleman                            Enter another Gentleman
# 111055   Second Gentleman                            Enter a third Gentleman
# 111143    First Gentleman                                   Exeunt Gentlemen
# 111155          AUTOLYCUS                           Enter Shepherd and Clown
# 111206              Clown                                             Exeunt
# 111207              Clown            SCENE III. A chapel in PAULINA'S house.
# 111208              Clown  Enter LEONTES, POLIXENES, FLORIZEL, PERDITA, C...
# 111232            PAULINA  PAULINA draws a curtain, and discovers HERMION...
# 111330            PAULINA                                              Music
# 111336            PAULINA                                HERMIONE comes down
# 111395            LEONTES                                             Exeunt
#
# [6243 rows x 6 columns]

# %%
df['ActSceneLine'].fillna("trans", inplace=True)

# %% [markdown]
# Finally, for Player we replace missing values with OTHER

# %%
df.loc[df['Player'].isnull()]
# Out:
#        Dataline       Play  PlayerLinenumber ActSceneLine Player  \
# 0             1   Henry IV               0.0        trans    NaN
# 1             2   Henry IV               0.0        trans    NaN
# 2             3   Henry IV               0.0        trans    NaN
# 2015       2016   Henry IV              10.0        trans    NaN
# 2016       2017   Henry IV              10.0        trans    NaN
# 29459     29460  Cymbeline               7.0       2.2.55    NaN
# 29460     29461  Cymbeline               7.0        trans    NaN
#
#                                               PlayerLine
# 0                                                  ACT I
# 1                           SCENE I. London. The palace.
# 2      Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 2015                  Eastcheap. The Boar's-Head Tavern.
# 2016                         Enter FALSTAFF and BARDOLPH
# 29459     An ante-chamber adjoining Imogen's apartments.
# 29460                             Enter CLOTEN and Lords

# %%
df['Player'].fillna("OTHER", inplace=True)

# %% [markdown]
# ## Rename the columns for more consistency

# %%
df.rename(index=str, columns={"PlayerLinenumber": "LineNumber", "PlayerLine": "Line"}, inplace=True)
df.drop(columns=["Dataline"], inplace=True)

# %%
df.head()
# Out:
#        Play  LineNumber ActSceneLine         Player  \
# 0  Henry IV         0.0        trans          OTHER
# 1  Henry IV         0.0        trans          OTHER
# 2  Henry IV         0.0        trans          OTHER
# 3  Henry IV         1.0        1.1.1  KING HENRY IV
# 4  Henry IV         1.0        1.1.2  KING HENRY IV
#
#                                                 Line
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %% [markdown]
# ## Create new columns for LineLength and MostCommonLetter

# %%
import collections
df['LineLength'] = df.apply(lambda row : len(row.Line), axis=1)
df['MostCommonLetter'] = df.apply(lambda row : ord(collections.Counter(row.Line.lower()).most_common(1)[0][0]), axis=1)

# %%
df.head()
# Out:
#        Play  LineNumber ActSceneLine         Player  \
# 0  Henry IV         0.0        trans          OTHER
# 1  Henry IV         0.0        trans          OTHER
# 2  Henry IV         0.0        trans          OTHER
# 3  Henry IV         1.0        1.1.1  KING HENRY IV
# 4  Henry IV         1.0        1.1.2  KING HENRY IV
#
#                                                 Line  LineLength  \
# 0                                              ACT I           5
# 1                       SCENE I. London. The palace.          28
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...          96
# 3             So shaken as we are, so wan with care,          38
# 4         Find we a time for frighted peace to pant,          42
#
#    MostCommonLetter
# 0                97
# 1               101
# 2                32
# 3                32
# 4                32

# %% [markdown]
# ## Create new columns for Polarity and Subjectivity of the sentiment in each line

# %%
from textblob import TextBlob

df['Polarity'] = df.apply(lambda row : TextBlob(row.Line).sentiment.polarity, axis=1)
df['Subjectivity'] = df.apply(lambda row : TextBlob(row.Line).sentiment.subjectivity, axis=1)

# %% [markdown]
# ## Doing some more feature engineering by splitting the ActSceneLine column into three different columns by parsing the string

# %%
def acs_split(string, index):
    if string == "trans":
        return 0
    else:
        return (int(string.split(".")[index]))

df['Act'] = df.apply(lambda row : acs_split(row.ActSceneLine, 0), axis=1)
df['Scene'] = df.apply(lambda row : acs_split(row.ActSceneLine, 1), axis=1)
df['ACSLineNum'] = df.apply(lambda row : acs_split(row.ActSceneLine, 2), axis=1)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %% [markdown]
# ## Create new columns that contain the encoding of the string values

# %%
df["PlayENC"] = le.fit_transform(df["Play"].astype(str))
df["PlayerENC"] = le.fit_transform(df["Player"].astype(str))
df["LineENC"] = le.fit_transform(df["Line"].astype(str))
df["ACSEnc"] = le.fit_transform(df["ActSceneLine"].astype(str))

# %%
df
# Out:
#                   Play  LineNumber ActSceneLine         Player  \
# 0             Henry IV         0.0        trans          OTHER
# 1             Henry IV         0.0        trans          OTHER
# 2             Henry IV         0.0        trans          OTHER
# 3             Henry IV         1.0        1.1.1  KING HENRY IV
# 4             Henry IV         1.0        1.1.2  KING HENRY IV
# 5             Henry IV         1.0        1.1.3  KING HENRY IV
# 6             Henry IV         1.0        1.1.4  KING HENRY IV
# 7             Henry IV         1.0        1.1.5  KING HENRY IV
# 8             Henry IV         1.0        1.1.6  KING HENRY IV
# 9             Henry IV         1.0        1.1.7  KING HENRY IV
# 10            Henry IV         1.0        1.1.8  KING HENRY IV
# 11            Henry IV         1.0        1.1.9  KING HENRY IV
# 12            Henry IV         1.0       1.1.10  KING HENRY IV
# 13            Henry IV         1.0       1.1.11  KING HENRY IV
# 14            Henry IV         1.0       1.1.12  KING HENRY IV
# 15            Henry IV         1.0       1.1.13  KING HENRY IV
# 16            Henry IV         1.0       1.1.14  KING HENRY IV
# 17            Henry IV         1.0       1.1.15  KING HENRY IV
# 18            Henry IV         1.0       1.1.16  KING HENRY IV
# 19            Henry IV         1.0       1.1.17  KING HENRY IV
# 20            Henry IV         1.0       1.1.18  KING HENRY IV
# 21            Henry IV         1.0       1.1.19  KING HENRY IV
# 22            Henry IV         1.0       1.1.20  KING HENRY IV
# 23            Henry IV         1.0       1.1.21  KING HENRY IV
# 24            Henry IV         1.0       1.1.22  KING HENRY IV
# 25            Henry IV         1.0       1.1.23  KING HENRY IV
# 26            Henry IV         1.0       1.1.24  KING HENRY IV
# 27            Henry IV         1.0       1.1.25  KING HENRY IV
# 28            Henry IV         1.0       1.1.26  KING HENRY IV
# 29            Henry IV         1.0       1.1.27  KING HENRY IV
# ...                ...         ...          ...            ...
# 111366  A Winters Tale        37.0      5.3.155        PAULINA
# 111367  A Winters Tale        37.0      5.3.156        PAULINA
# 111368  A Winters Tale        37.0      5.3.157        PAULINA
# 111369  A Winters Tale        37.0      5.3.158        PAULINA
# 111370  A Winters Tale        37.0      5.3.159        PAULINA
# 111371  A Winters Tale        37.0      5.3.160        PAULINA
# 111372  A Winters Tale        37.0      5.3.161        PAULINA
# 111373  A Winters Tale        37.0      5.3.162        PAULINA
# 111374  A Winters Tale        38.0      5.3.163        LEONTES
# 111375  A Winters Tale        38.0      5.3.164        LEONTES
# 111376  A Winters Tale        38.0      5.3.165        LEONTES
# 111377  A Winters Tale        38.0      5.3.166        LEONTES
# 111378  A Winters Tale        38.0      5.3.167        LEONTES
# 111379  A Winters Tale        38.0      5.3.168        LEONTES
# 111380  A Winters Tale        38.0      5.3.169        LEONTES
# 111381  A Winters Tale        38.0      5.3.170        LEONTES
# 111382  A Winters Tale        38.0      5.3.171        LEONTES
# 111383  A Winters Tale        38.0      5.3.172        LEONTES
# 111384  A Winters Tale        38.0      5.3.173        LEONTES
# 111385  A Winters Tale        38.0      5.3.174        LEONTES
# 111386  A Winters Tale        38.0      5.3.175        LEONTES
# 111387  A Winters Tale        38.0      5.3.176        LEONTES
# 111388  A Winters Tale        38.0      5.3.177        LEONTES
# 111389  A Winters Tale        38.0      5.3.178        LEONTES
# 111390  A Winters Tale        38.0      5.3.179        LEONTES
# 111391  A Winters Tale        38.0      5.3.180        LEONTES
# 111392  A Winters Tale        38.0      5.3.181        LEONTES
# 111393  A Winters Tale        38.0      5.3.182        LEONTES
# 111394  A Winters Tale        38.0      5.3.183        LEONTES
# 111395  A Winters Tale        38.0        trans        LEONTES
#
#                                                      Line  LineLength  \
# 0                                                   ACT I           5
# 1                            SCENE I. London. The palace.          28
# 2       Enter KING HENRY, LORD JOHN OF LANCASTER, the ...          96
# 3                  So shaken as we are, so wan with care,          38
# 4              Find we a time for frighted peace to pant,          42
# 5          And breathe short-winded accents of new broils          46
# 6                 To be commenced in strands afar remote.          39
# 7               No more the thirsty entrance of this soil          41
# 8       Shall daub her lips with her own children's bl...          50
# 9        Nor more shall trenching war channel her fields,          48
# 10          Nor bruise her flowerets with the armed hoofs          45
# 11                  Of hostile paces: those opposed eyes,          37
# 12          Which, like the meteors of a troubled heaven,          45
# 13              All of one nature, of one substance bred,          41
# 14                 Did lately meet in the intestine shock          38
# 15                    And furious close of civil butchery          35
# 16             Shall now, in mutual well-beseeming ranks,          42
# 17               March all one way and be no more opposed          40
# 18              Against acquaintance, kindred and allies:          41
# 19           The edge of war, like an ill-sheathed knife,          44
# 20      No more shall cut his master. Therefore, friends,          49
# 21                  As far as to the sepulchre of Christ,          37
# 22           Whose soldier now, under whose blessed cross          44
# 23                 We are impressed and engaged to fight,          38
# 24            Forthwith a power of English shall we levy,          43
# 25         Whose arms were moulded in their mothers' womb          46
# 26             To chase these pagans in those holy fields          42
# 27             Over whose acres walk'd those blessed feet          42
# 28           Which fourteen hundred years ago were nail'd          44
# 29                 For our advantage on the bitter cross.          38
# ...                                                   ...         ...
# 111366                      There's time enough for that,          29
# 111367         Lest they desire upon this push to trouble          42
# 111368         Your joys with like relation. Go together,          42
# 111369          You precious winners all, your exultation          41
# 111370            Partake to every one. I, an old turtle,          39
# 111371      Will wing me to some wither'd bough and there          45
# 111372           My mate, that's never to be found again,          40
# 111373                             Lament till I am lost.          22
# 111374                                 O, peace, Paulina!          18
# 111375        Thou shouldst a husband take by my consent,          43
# 111376             As I by thine a wife: this is a match,          38
# 111377  And made between's by vows. Thou hast found mine,          49
# 111378       But how, is to be question'd, for I saw her,          44
# 111379     As I thought, dead, and have in vain said many          46
# 111380       A prayer upon her grave. I'll not seek far--          44
# 111381      For him, I partly know his mind--to find thee          45
# 111382              An honourable husband. Come, Camillo,          37
# 111383  And take her by the hand, whose worth and honesty          49
# 111384                 Is richly noted and here justified          34
# 111385     By us, a pair of kings. Let's from this place.          46
# 111386     What! look upon my brother: both your pardons,          46
# 111387            That e'er I put between your holy looks          39
# 111388         My ill suspicion. This is your son-in-law,          42
# 111389     And son unto the king, who, heavens directing,          46
# 111390    Is troth-plight to your daughter. Good Paulina,          47
# 111391         Lead us from hence, where we may leisurely          42
# 111392              Each one demand an answer to his part          37
# 111393     Perform'd in this wide gap of time since first          46
# 111394             We were dissever'd: hastily lead away.          38
# 111395                                             Exeunt           6
#
#         MostCommonLetter  Polarity  Subjectivity  Act  Scene  ACSLineNum  \
# 0                     97  0.000000      0.000000    0      0           0
# 1                    101  0.000000      0.000000    0      0           0
# 2                     32  0.000000      0.000000    0      0           0
# 3                     32 -0.200000      0.150000    1      1           1
# 4                     32  0.000000      0.000000    1      1           2
# 5                     32  0.136364      0.454545    1      1           3
# 6                     32 -0.100000      0.200000    1      1           4
# 7                     32 -0.250000      0.500000    1      1           5
# 8                     32  0.600000      1.000000    1      1           6
# 9                     32  0.500000      0.500000    1      1           7
# 10                    32  0.000000      0.000000    1      1           8
# 11                   101  0.000000      0.000000    1      1           9
# 12                    32 -0.500000      1.000000    1      1          10
# 13                    32  0.000000      0.000000    1      1          11
# 14                    32 -0.300000      0.600000    1      1          12
# 15                    32  0.000000      0.000000    1      1          13
# 16                   108  0.000000      0.000000    1      1          14
# 17                    32 -0.250000      0.500000    1      1          15
# 18                    97  0.000000      0.000000    1      1          16
# 19                   101  0.000000      0.000000    1      1          17
# 20                    32 -0.250000      0.500000    1      1          18
# 21                    32  0.100000      1.000000    1      1          19
# 22                   115  0.000000      0.000000    1      1          20
# 23                   101  1.000000      1.000000    1      1          21
# 24                    32  0.000000      0.000000    1      1          22
# 25                    32  0.000000      0.000000    1      1          23
# 26                    32  0.000000      0.000000    1      1          24
# 27                   101  0.000000      0.000000    1      1          25
# 28                    32  0.000000      0.000000    1      1          26
# 29                    32 -0.050000      0.250000    1      1          27
# ...                  ...       ...           ...  ...    ...         ...
# 111366               116  0.000000      0.500000    5      3         155
# 111367                32 -0.200000      0.200000    5      3         156
# 111368                32  0.000000      0.000000    5      3         157
# 111369                32  0.500000      1.000000    5      3         158
# 111370                32  0.100000      0.200000    5      3         159
# 111371                32  0.000000      0.000000    5      3         160
# 111372                32  0.000000      0.000000    5      3         161
# 111373               108  0.000000      0.000000    5      3         162
# 111374                97  0.000000      0.000000    5      3         163
# 111375                32  0.000000      0.000000    5      3         164
# 111376                32  0.000000      0.000000    5      3         165
# 111377                32  0.000000      0.000000    5      3         166
# 111378                32  0.000000      0.000000    5      3         167
# 111379                32  0.150000      0.450000    5      3         168
# 111380                32  0.100000      1.000000    5      3         169
# 111381                32  0.000000      0.000000    5      3         170
# 111382                97  0.000000      0.000000    5      3         171
# 111383                32  0.300000      0.100000    5      3         172
# 111384                32  0.387500      0.825000    5      3         173
# 111385                32  0.000000      0.000000    5      3         174
# 111386                32  0.000000      0.000000    5      3         175
# 111387                32  0.000000      0.000000    5      3         176
# 111388                32 -0.500000      1.000000    5      3         177
# 111389                32  0.000000      0.000000    5      3         178
# 111390                32  0.700000      0.600000    5      3         179
# 111391               101  0.000000      0.000000    5      3         180
# 111392                32  0.000000      0.000000    5      3         181
# 111393                32  0.075000      0.366667    5      3         182
# 111394               101  0.000000      0.000000    5      3         183
# 111395               101  0.000000      0.000000    0      0           0
#
#         PlayENC  PlayerENC  LineENC  ACSEnc
# 0             9        617     2574   16122
# 1             9        617    60108   16122
# 2             9        617    23218   16122
# 3             9        457    63734     324
# 4             9        457    25781     435
# 5             9        457     5120     546
# 6             9        457    77594     657
# 7             9        457    51386     768
# 8             9        457    61525     781
# 9             9        457    52258     792
# 10            9        457    52142     803
# 11            9        457    55407     814
# 12            9        457    87603     325
# 13            9        457     3633     336
# 14            9        457    21134     347
# 15            9        457     5938     358
# 16            9        457    61627     369
# 17            9        457    47443     380
# 18            9        457     2959     391
# 19            9        457    69975     402
# 20            9        457    51372     413
# 21            9        457    12015     424
# 22            9        457    88688     436
# 23            9        457    82253     447
# 24            9        457    27740     458
# 25            9        457    88527     469
# 26            9        457    77853     480
# 27            9        457    57624     491
# 28            9        457    87004     502
# 29            9        457    26908     513
# ...         ...        ...      ...     ...
# 111366        2        632    73502   14575
# 111367        2        632    45391   14576
# 111368        2        632    93868   14577
# 111369        2        632    93091   14578
# 111370        2        632    57762   14579
# 111371        2        632    89958   14581
# 111372        2        632    50014   14582
# 111373        2        632    45084   14583
# 111374        2        494    54692   14584
# 111375        2        494    76020   14585
# 111376        2        494    11719   14586
# 111377        2        494     7078   14587
# 111378        2        494    16513   14588
# 111379        2        494    11795   14589
# 111380        2        494     2078   14590
# 111381        2        494    26637   14592
# 111382        2        494     4109   14593
# 111383        2        494     8707   14594
# 111384        2        494    43517   14595
# 111385        2        494    18565   14596
# 111386        2        494    84960   14597
# 111387        2        494    67070   14598
# 111388        2        494    49634   14599
# 111389        2        494     8534   14600
# 111390        2        494    43721   14601
# 111391        2        494    45207   14603
# 111392        2        494    22350   14604
# 111393        2        494    58003   14605
# 111394        2        494    82723   14606
# 111395        2        494    24488   16122
#
# [111396 rows x 16 columns]

# %% [markdown]
# ## Split the data into testing and training set

# %%
from sklearn.model_selection import train_test_split

X = df[['LineLength', 'MostCommonLetter', 'Polarity', 'Subjectivity', 'Act', 'Scene', 'ACSLineNum', 'ACSEnc', 'PlayENC','LineENC']]
Y = df['PlayerENC']
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.2)

# %% [markdown]
# ## Running two different classifiers, Random Forest and Desicion Tree

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()

# %%
random_forest.fit(X_train, Y_train)
rf_predict = random_forest.predict(X_test)

# %% [markdown]
# ### We get a decent prediction accuracy with random forest of about 60.9%

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, rf_predict)
# Out:
# 0.6092908438061041

# %% [markdown]
# ### Surpisingly, we get a somewhat better prediction accuracy rate of 63.3% using a decision tree

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(X_train, Y_train)
dt_predict = model.predict(X_test)
accuracy_score(Y_test, dt_predict)
# Out:
# 0.6326750448833034
